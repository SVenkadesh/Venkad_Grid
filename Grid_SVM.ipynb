# %%
#importing the Libraies

import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
# The Dataset have Categorical data type then using Nominal function
dataset=pd.get_dummies(dataset,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
indep=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dep=dataset[['charges']]

# %%
# SVM Regression
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
#Param_grid = {'kernel':['linear', 'poly', 'rbf', 'sigmoid'], 'gamma':['scale', 'auto'],'C':[10,100,1000,2000,300]}
Param_grid = {'kernel':['linear','rbf', 'sigmoid'], 'gamma':['scale', 'auto'],'C':[10,100,1000,2000,300]}
grid=GridSearchCV(SVR(),Param_grid,refit=True,verbose=3,n_jobs=-1)

grid.fit(indep,dep)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# C:\Users\venka\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [10, 100, 1000, 2000, 300],
#                          'gamma': ['scale', 'auto'],
#                          'kernel': ['linear', 'rbf', 'sigmoid']},
#              verbose=3)

# %%
prnt = grid.cv_results_
table=pd.DataFrame.from_dict(prnt)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.614973      0.073083         0.085548        0.020068      10
# 1        0.663960      0.073844         0.279889        0.018860      10
# 2        0.649433      0.134822         0.168437        0.041385      10
# 3        0.622624      0.094432         0.087294        0.004769      10
# 4        1.033861      0.028554         0.285188        0.022975      10
# 5        0.548341      0.003823         0.109371        0.011111      10
# 6        1.270860      0.057118         0.093366        0.008714     100
# 7        0.721729      0.013585         0.268890        0.013811     100
# 8        0.853644      0.019333         0.150360        0.008350     100
# 9        1.233661      0.032895         0.092177        0.010352     100
# 10       1.023259      0.075911         0.285846        0.015833     100
# 11       0.541328      0.029580         0.108499        0.008029     100
# 12       4.406062      0.457700         0.089089        0.004876    1000
# 13       0.728910      0.020109         0.273248        0.018795    1000
# 14       0.794778      0.033276         0.177363        0.003177    1000
# 15       4.416112      0.421699         0.094336        0.005552    1000
# 16       1.451655      0.035720         0.291646        0.014298    1000
# 17       0.520173      0.013973         0.106717        0.010201    1000
# 18       7.082024      0.457244         0.092859        0.007749    2000
# 19       0.757502      0.038697         0.278398        0.014297    2000
# 20       0.776680      0.017117         0.170976        0.008736    2000
# 21       7.104504      0.493751         0.075340        0.018690    2000
# 22       2.005846      0.104998         0.290963        0.010839    2000
# 23       0.522236      0.016633         0.105606        0.009120    2000
# 24       2.347726      0.139793         0.090884        0.005758     300
# 25       0.722646      0.022949         0.277116        0.015884     300
# 26       0.850855      0.023524         0.161087        0.003303     300
# 27       2.068481      0.166913         0.041645        0.021302     300
# 28       1.162853      0.023692         0.241412        0.015174     300
# 29       0.510153      0.021237         0.094230        0.006279     300
#
#    param_gamma param_kernel  \
# 0        scale       linear
# 1        scale          rbf
# 2        scale      sigmoid
# 3         auto       linear
# 4         auto          rbf
# 5         auto      sigmoid
# 6        scale       linear
# 7        scale          rbf
# 8        scale      sigmoid
# 9         auto       linear
# 10        auto          rbf
# 11        auto      sigmoid
# 12       scale       linear
# 13       scale          rbf
# 14       scale      sigmoid
# 15        auto       linear
# 16        auto          rbf
# 17        auto      sigmoid
# 18       scale       linear
# 19       scale          rbf
# 20       scale      sigmoid
# 21        auto       linear
# 22        auto          rbf
# 23        auto      sigmoid
# 24       scale       linear
# 25       scale          rbf
# 26       scale      sigmoid
# 27        auto       linear
# 28        auto          rbf
# 29        auto      sigmoid
#
#                                                params  split0_test_score  \
# 0     {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}          -0.018943
# 1        {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}          -0.110409
# 2    {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}          -0.116743
# 3      {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}          -0.018943
# 4         {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}          -0.113791
# 5     {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.115328
# 6    {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}           0.559313
# 7       {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}          -0.160182
# 8   {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}          -0.142455
# 9     {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}           0.559313
# 10       {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}          -0.100012
# 11   {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.115328
# 12  {'C': 1000, 'gamma': 'scale', 'kernel': 'linear'}           0.736398
# 13     {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}          -0.155430
# 14  {'C': 1000, 'gamma': 'scale', 'kernel': 'sigmo...          -2.043140
# 15   {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}           0.736398
# 16      {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}          -0.080692
# 17  {'C': 1000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.115328
# 18  {'C': 2000, 'gamma': 'scale', 'kernel': 'linear'}           0.682349
# 19     {'C': 2000, 'gamma': 'scale', 'kernel': 'rbf'}          -0.143510
# 20  {'C': 2000, 'gamma': 'scale', 'kernel': 'sigmo...          -7.209317
# 21   {'C': 2000, 'gamma': 'auto', 'kernel': 'linear'}           0.682349
# 22      {'C': 2000, 'gamma': 'auto', 'kernel': 'rbf'}          -0.033126
# 23  {'C': 2000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.115328
# 24   {'C': 300, 'gamma': 'scale', 'kernel': 'linear'}           0.617758
# 25      {'C': 300, 'gamma': 'scale', 'kernel': 'rbf'}          -0.164126
# 26  {'C': 300, 'gamma': 'scale', 'kernel': 'sigmoid'}          -0.293600
# 27    {'C': 300, 'gamma': 'auto', 'kernel': 'linear'}           0.617758
# 28       {'C': 300, 'gamma': 'auto', 'kernel': 'rbf'}          -0.081243
# 29   {'C': 300, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.115328
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.029886           0.022167           0.003112
# 1           -0.097459          -0.074488          -0.099597
# 2           -0.119312          -0.085214          -0.108210
# 3            0.029886           0.022167           0.003112
# 4           -0.110741          -0.079156          -0.103389
# 5           -0.113567          -0.081608          -0.106067
# 6            0.521798           0.547691           0.538805
# 7           -0.107253          -0.123430          -0.137753
# 8           -0.160831          -0.117544          -0.137984
# 9            0.521798           0.547691           0.538805
# 10          -0.098456          -0.072981          -0.096615
# 11          -0.113567          -0.081608          -0.106067
# 12           0.675162           0.680002           0.699377
# 13          -0.098267          -0.123724          -0.137137
# 14          -2.686121          -2.194563          -2.210858
# 15           0.675162           0.680002           0.699377
# 16          -0.054347          -0.062876          -0.079329
# 17          -0.113567          -0.081608          -0.106067
# 18           0.630642           0.750714           0.646368
# 19          -0.087595          -0.113312          -0.128591
# 20          -9.282940          -7.776578          -7.745074
# 21           0.630642           0.750714           0.646368
# 22          -0.002835          -0.026545          -0.029140
# 23          -0.113567          -0.081608          -0.106067
# 24           0.575264           0.603577           0.594633
# 25          -0.107700          -0.128180          -0.139809
# 26          -0.348392          -0.278722          -0.298268
# 27           0.575264           0.603577           0.594633
# 28          -0.078949          -0.066217          -0.092394
# 29          -0.113567          -0.081608          -0.106067
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           -0.066653        -0.006086        0.034672                9
# 1           -0.124428        -0.101276        0.016459               15
# 2           -0.108716        -0.107639        0.012029               22
# 3           -0.066653        -0.006086        0.034672                9
# 4           -0.106488        -0.102713        0.012303               16
# 5           -0.107195        -0.104753        0.012107               17
# 6            0.508518         0.535225        0.018122                7
# 7           -0.209551        -0.147634        0.035511               26
# 8           -0.130402        -0.137843        0.014263               24
# 9            0.508518         0.535225        0.018122                7
# 10          -0.102232        -0.094059        0.010699               14
# 11          -0.107195        -0.104753        0.012107               17
# 12           0.677952         0.693778        0.022955                1
# 13          -0.206405        -0.144193        0.036262               25
# 14          -1.942521        -2.215441        0.255409               29
# 15           0.677952         0.693778        0.022955                1
# 16          -0.117983        -0.079045        0.021865               12
# 17          -0.107195        -0.104753        0.012107               17
# 18           0.722261         0.686467        0.045056                3
# 19          -0.193992        -0.133400        0.035492               23
# 20          -6.891719        -7.781126        0.821557               30
# 21           0.722261         0.686467        0.045056                3
# 22          -0.067392        -0.031808        0.020699               11
# 23          -0.107195        -0.104753        0.012107               17
# 24           0.575552         0.593357        0.016406                5
# 25          -0.216221        -0.151207        0.037274               27
# 26          -0.260641        -0.295925        0.029342               28
# 27           0.575552         0.593357        0.016406                5
# 28          -0.102701        -0.084300        0.012402               13
# 29          -0.107195        -0.104753        0.012107               17

# %%
print("The best r2 value{}:".format(grid.best_params_))
# Out:
# The best r2 value{'C': 1000, 'gamma': 'scale', 'kernel': 'linear'}:
